# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np
import re
from pathlib import Path

# %% [markdown]
# ## Prepare AACT Data for NER Annotation

# %%
aact_data = pd.read_csv("data/raw_aact/combined_neuro_trials_with_interventions_20240313.csv")[['nct_id','study_official_title', 'brief_summary_description']].drop_duplicates()
aact_data.shape
# Out:
# (46376, 3)

# %%
len(set(aact_data['nct_id']))
# Out:
# 46376

# %%
# Create a new column 'text' by concatenating 'study_official_title' and 'brief_summary_description'
aact_data['text'] = aact_data['study_official_title'].fillna('') + '| ' + aact_data['brief_summary_description'].fillna('')

# Display the updated DataFrame
aact_data.head()
# Out:
#          nct_id                               study_official_title  \
# 0   NCT03890861  Reducing African Americans' Alzheimer's Diseas...
# 6   NCT03060096  Stepped-Care Telehealth for Distress in Cancer...
# 12  NCT04525742  COVID-19 Pandemic From the Perspective of Pare...
# 15  NCT02324634  Early Electrical Stimulation to the Wrist Exte...
# 18  NCT06036368  6-weeks, Open-label, Single-Site Study to Eval...
#
#                             brief_summary_description  \
# 0   The RAATE proposal is designed to determine th...
# 6   Mental health issues in post-treatment adult c...
# 12  Pandemic period could affect the disabled chil...
# 15  Stroke is the largest cause of adult disabilit...
# 18  This is a 6-week exploratory clinical study, d...
#
#                                                  text
# 0   Reducing African Americans' Alzheimer's Diseas...
# 6   Stepped-Care Telehealth for Distress in Cancer...
# 12  COVID-19 Pandemic From the Perspective of Pare...
# 15  Early Electrical Stimulation to the Wrist Exte...
# 18  6-weeks, Open-label, Single-Site Study to Eval...

# %%
aact_data.to_csv(f"data/aact_for_ner/aact_texts_{len(aact_data)}.csv")

# %% [markdown]
# # Prep annotated data for TSNE embedding

# %%
reference_data_new = pd.read_csv("data/raw_aact/combined_neuro_trials_with_interventions_20240313.csv")[['nct_id','brief_title', 'start_date', 'study_official_title', 'brief_summary_description']].drop_duplicates()

# %%
reference_data_new.head()
# Out:
#          nct_id                                        brief_title  \
# 0   NCT03890861  Reducing African Americans' Alzheimer's Diseas...
# 6   NCT03060096  Stepped-Care Telehealth for Distress in Cancer...
# 12  NCT04525742  COVID-19 Pandemic and Parents of Disabled Chil...
# 15  NCT02324634  Early Electrical Stimulation to Prevent Compli...
# 18  NCT06036368  Study to Evaluate Safety and Efficacy of Peron...
#
#     start_date                               study_official_title  \
# 0   2019-08-09  Reducing African Americans' Alzheimer's Diseas...
# 6   2018-07-19  Stepped-Care Telehealth for Distress in Cancer...
# 12  2020-07-05  COVID-19 Pandemic From the Perspective of Pare...
# 15  2015-06-01  Early Electrical Stimulation to the Wrist Exte...
# 18  2023-09-15  6-weeks, Open-label, Single-Site Study to Eval...
#
#                             brief_summary_description
# 0   The RAATE proposal is designed to determine th...
# 6   Mental health issues in post-treatment adult c...
# 12  Pandemic period could affect the disabled chil...
# 15  Stroke is the largest cause of adult disabilit...
# 18  This is a 6-week exploratory clinical study, d...

# %%
reference_data_new.shape
# Out:
# (46376, 5)

# %%
data_path = Path("data/annotated_aact/")

# %%
df_annotations_all = pd.read_csv(data_path/ "ner_outputs/aggregated_ner_annotations_basic_dict_mapped_19632.csv")

# %%
model_prefix = "combined_union"
entity_types = ["conditions", "interventions"]
if model_prefix == "linkbert":
    mapped_size = [18212, 16917]
elif model_prefix == "aact":
    mapped_size = [19632, 18720]
else:
    mapped_size = [19632, 19632]

# %%
# Loop through each entity type, read the corresponding file, and perform the join
for entity_type, mapped_nr in zip(entity_types, mapped_size):
    # Construct the file path
    file_path = data_path / f"snomed_linking_outputs/mapped_to_hierarchy/aact_bert_combined/hierarchical_mapping_to_snomed_{model_prefix}_{entity_type}_aggregated_{mapped_nr}.csv"
    
    # Read the data
    df_entity = pd.read_csv(file_path, index_col=0)
    
    # Perform the left join on nct_id
    df_annotations_all = df_annotations_all.merge(df_entity, on='nct_id', how='left')

if model_prefix == "combined":
    df_annotations_all[f'canonical_combined_{entity_type}'] = df_annotations_all[f'canonical_BioLinkBERT-base_{entity_type}'].combine_first(df_annotations_all[f'canonical_aact_{entity_type}'])

# %%
df_annotations_all.shape
# Out:
# (19632, 20)

# %%
df_annotations_all.head()
# Out:
#    Unnamed: 0       nct_id canonical_BioLinkBERT-base_interventions  \
# 0           0  NCT00000117          intravenous immunoglobulin|ivig
# 1           1  NCT00000146                           corticosteroid
# 2           2  NCT00000147                           corticosteroid
# 3           3  NCT00000151             acetylsalicylic acid|aspirin
# 4           4  NCT00000170                                 atropine
#
#     canonical_aact_interventions aact_intervention_types  \
# 0                 immunoglobulin                    Drug
# 1  prednisone|methylprednisolone                    Drug
# 2  prednisone|methylprednisolone                    Drug
# 3   aspirin|acetylsalicylic acid          Procedure|Drug
# 4                       atropine             Drug|Device
#
#                canonical_BioLinkBERT-base_conditions  \
# 0                  multiple sclerosis|optic neuritis
# 1                  multiple sclerosis|optic neuritis
# 2                  multiple sclerosis|optic neuritis
# 3  diabetes mellitus|diabetic retinopathy|early d...
# 4  amblyopia|anisometropia|moderate amblyopia|str...
#
#            canonical_aact_conditions  \
# 0                     optic neuritis
# 1  optic neuritis|multiple sclerosis
# 2  optic neuritis|multiple sclerosis
# 3                          blindness
# 4                          amblyopia
#
#                                    Disease Class  \
# 0                         Cranial Nerve Diseases
# 1  Demyelinating Diseases|Cranial Nerve Diseases
# 2  Demyelinating Diseases|Cranial Nerve Diseases
# 3                      Neurologic Manifestations
# 4                      Neurologic Manifestations
#
#            linkbert_snomed_term_canonical_conditions  \
# 0  Multiple sclerosis (disorder)|Optic neuritis (...
# 1  Multiple sclerosis (disorder)|Optic neuritis (...
# 2  Multiple sclerosis (disorder)|Optic neuritis (...
# 3  Diabetes mellitus (disorder)|Retinopathy due t...
# 4  Amblyopia (disorder)|Anisometropia (disorder)|...
#
#      linkbert_top_concept_canonical_first_conditions  \
# 0  Multiple sclerosis (disorder)|Optic neuritis (...
# 1  Multiple sclerosis (disorder)|Optic neuritis (...
# 2  Multiple sclerosis (disorder)|Optic neuritis (...
# 3  Diabetes mellitus (disorder)|Retinal disorder ...
# 4  Amblyopia (disorder)|Anisometropia (disorder)|...
#
#                aact_snomed_term_canonical_conditions  \
# 0                          Optic neuritis (disorder)
# 1  Optic neuritis (disorder)|Multiple sclerosis (...
# 2  Optic neuritis (disorder)|Multiple sclerosis (...
# 3                         Legal blindness (disorder)
# 4                               Amblyopia (disorder)
#
#          aact_top_concept_canonical_first_conditions  \
# 0                          Optic neuritis (disorder)
# 1  Optic neuritis (disorder)|Multiple sclerosis (...
# 2  Optic neuritis (disorder)|Multiple sclerosis (...
# 3                         Legal blindness (disorder)
# 4                               Amblyopia (disorder)
#
#      combined_union_snomed_term_canonical_conditions  \
# 0  Multiple sclerosis (disorder)|Optic neuritis (...
# 1  Multiple sclerosis (disorder)|Optic neuritis (...
# 2  Multiple sclerosis (disorder)|Optic neuritis (...
# 3  Diabetes mellitus (disorder)|Legal blindness (...
# 4  Amblyopia (disorder)|Anisometropia (disorder)|...
#
#   combined_union_top_concept_canonical_first_conditions  \
# 0  Multiple sclerosis (disorder)|Optic neuritis (...
# 1  Multiple sclerosis (disorder)|Optic neuritis (...
# 2  Multiple sclerosis (disorder)|Optic neuritis (...
# 3  Diabetes mellitus (disorder)|Legal blindness (...
# 4  Amblyopia (disorder)|Anisometropia (disorder)|...
#
#         linkbert_snomed_term_canonical_interventions  \
# 0                         Immunoglobulin (substance)
# 1  Corticosteroid and/or corticosteroid derivativ...
# 2  Corticosteroid and/or corticosteroid derivativ...
# 3                                Aspirin (substance)
# 4                               Atropine (substance)
#
#   linkbert_top_concept_canonical_first_interventions  \
# 0                         Immunoglobulin (substance)
# 1  Corticosteroid and/or corticosteroid derivativ...
# 2  Corticosteroid and/or corticosteroid derivativ...
# 3                              Analgesic (substance)
# 4                         Bronchodilator (substance)
#
#             aact_snomed_term_canonical_interventions  \
# 0                         Immunoglobulin (substance)
# 1  Prednisone (substance)|Methylprednisolone (sub...
# 2  Prednisone (substance)|Methylprednisolone (sub...
# 3                                Aspirin (substance)
# 4                               Atropine (substance)
#
#       aact_top_concept_canonical_first_interventions  \
# 0                        Blood component (substance)
# 1  Corticosteroid and/or corticosteroid derivativ...
# 2  Corticosteroid and/or corticosteroid derivativ...
# 3                              Analgesic (substance)
# 4                               Antidote (substance)
#
#   combined_union_snomed_term_canonical_interventions  \
# 0                         Immunoglobulin (substance)
# 1  Corticosteroid and/or corticosteroid derivativ...
# 2  Corticosteroid and/or corticosteroid derivativ...
# 3                                Aspirin (substance)
# 4                               Atropine (substance)
#
#   combined_union_top_concept_canonical_first_interventions
# 0  Blood component (substance)|Immunoglobulin (su...
# 1  Corticosteroid and/or corticosteroid derivativ...
# 2  Corticosteroid and/or corticosteroid derivativ...
# 3                              Analgesic (substance)
# 4    Antidote (substance)|Bronchodilator (substance)

# %%
evaluate_snomed_link = True
hierarchical_mapping_conditions = True
hierarchical_mapping_interventions = False

if  model_prefix == "linkbert":
    target_ner_column_prefix = 'canonical_BioLinkBERT-base'
elif model_prefix == "aact":
    target_ner_column_prefix = 'canonical_aact'
else:
    target_ner_column_prefix = 'canonical_combined'

if evaluate_snomed_link:
    if hierarchical_mapping_conditions and hierarchical_mapping_interventions:
        target_interventions_column = f'{model_prefix}_top_concept_canonical_first_interventions'
        target_conditions_column = f'{model_prefix}_top_concept_canonical_first_conditions'
        annotations_type = f'{model_prefix}_sapbert_hierarchical'
    elif hierarchical_mapping_conditions and (not hierarchical_mapping_interventions):
        target_interventions_column = f'{model_prefix}_snomed_term_canonical_interventions'
        target_conditions_column = f'{model_prefix}_top_concept_canonical_first_conditions'
        annotations_type = f'{model_prefix}_sapbert_cond_hier'
    elif hierarchical_mapping_interventions and (not hierarchical_mapping_conditions):
        target_interventions_column = f'{model_prefix}_top_concept_canonical_first_interventions'
        target_conditions_column = f'{model_prefix}_snomed_term_canonical_conditions'
        annotations_type = f'{model_prefix}_sapbert_interv_hier'
    else:
        target_interventions_column = f'{model_prefix}_snomed_term_canonical_interventions'
        target_conditions_column = f'{model_prefix}_snomed_term_canonical_conditions'
        annotations_type = f'{model_prefix}_sapbert'
else:
    target_interventions_column = f'{target_ner_column_prefix}_interventions'
    target_conditions_column = f'{target_ner_column_prefix}_conditions'
    annotations_type = model_prefix

# %%
df_normalized_annotations = df_annotations_all[['nct_id', target_interventions_column, target_conditions_column]]
reference_data_with_target_annotations = df_normalized_annotations.merge(reference_data_new, on='nct_id', how='left')
reference_data_with_target_annotations.head(2)
# Out:
#         nct_id combined_union_snomed_term_canonical_interventions  \
# 0  NCT00000117                         Immunoglobulin (substance)
# 1  NCT00000146  Corticosteroid and/or corticosteroid derivativ...
#
#   combined_union_top_concept_canonical_first_conditions  \
# 0  Multiple sclerosis (disorder)|Optic neuritis (...
# 1  Multiple sclerosis (disorder)|Optic neuritis (...
#
#                                          brief_title  start_date  \
# 0  Intravenous Immunoglobulin Therapy in Optic Ne...  1995-08-31
# 1              Optic Neuritis Treatment Trial (ONTT)  1988-07-31
#
#   study_official_title                          brief_summary_description
# 0                  NaN  To determine whether high-dose intravenous imm...
# 1                  NaN  To assess the beneficial and adverse effects o...

# %%
df_normalized_annotations.shape
# Out:
# (19632, 3)

# %%
reference_data_with_target_annotations.shape
# Out:
# (19632, 7)

# %%
# Extract the year from 'start_date' and 'completion_date'
reference_data_with_target_annotations['start_date'] = pd.to_datetime(reference_data_with_target_annotations['start_date'])
reference_data_with_target_annotations['start_year'] = reference_data_with_target_annotations['start_date'].dt.year

reference_data_with_target_annotations = reference_data_with_target_annotations[reference_data_with_target_annotations['start_year']<2024]
reference_data_with_target_annotations = reference_data_with_target_annotations[reference_data_with_target_annotations['start_year']>=2000]

# %%
reference_data_with_target_annotations.shape
# Out:
# (18609, 8)

# %%
reference_data_with_target_annotations
# Out:
#             nct_id combined_union_snomed_term_canonical_interventions  \
# 89     NCT00000307                             Naltrexone (substance)
# 106    NCT00000333  Atropine (substance)|Benzatropine (substance)|...
# 145    NCT00000428  Amitriptyline (substance)|Fluoxetine (substanc...
# 146    NCT00000439  Sodium valproate (substance)|Valproate (substa...
# 220    NCT00001956  Ketorolac (substance)|Lidocaine (substance)|Mi...
# ...            ...                                                ...
# 19606  NCT06282640  Blood group antigen V (substance)|Ergocalcifer...
# 19613  NCT06287502             2-methyl-3-hydroxybutyrate (substance)
# 19616  NCT06289335  Dexmedetomidine (substance)|Ondansetron (subst...
# 19623  NCT06292351  Dimetan (substance)|N-methyl-1-(1,3-benzodioxo...
# 19626  NCT06293586                            Paracetamol (substance)
#
#       combined_union_top_concept_canonical_first_conditions  \
# 89     Disorder caused by alcohol (disorder)|Disorder...
# 106        Cocaine|Disorder caused by cocaine (disorder)
# 145                              Fibromyalgia (disorder)
# 146    Bipolar disorder (disorder)|Disorder caused by...
# 220    Central pain syndrome (disorder)|Disorder of m...
# ...                                                  ...
# 19606  Cts|Median neuropathy (disorder)|Pain|Peripher...
# 19613  Degenerative disorder of muscle (disorder)|Ost...
# 19616  Complication of surgical procedure (disorder)|...
# 19623  Alzheimer's disease (disorder)|Dementia (disor...
# 19626  Acute disease of cardiovascular system (disord...
#
#                                              brief_title start_date  \
# 89     Naltrexone as Adjunct in Alcoholic Cocaine Dep... 2003-04-30
# 106    Evaluation of Benztropine for Cocaine Craving - 2 2001-05-31
# 145    Combining N-of-1 Trials to Assess Fibromyalgia... 2000-09-30
# 146    Drug Treatment for Alcoholics With Bipolar Dis... 2000-10-31
# 220            Influence of Genetics in Pain Sensitivity 2000-01-31
# ...                                                  ...        ...
# 19606  Comparıson Of Electromyography Results Before ... 2021-12-30
# 19613  Efficacy of Structured Exercise-Nutritional In... 2022-09-09
# 19616  Dexmedetomidine Compared to Ondansetron for Po... 2020-08-05
# 19623  DMB-I in the Treatment of Alzheimer Type Dementia 2023-12-27
# 19626  Comparison Between Peribulbar And Sub-tenon Bl... 2023-12-01
#
#                                     study_official_title  \
# 89     Naltrexone as an Adjunct in Alcoholic Cocaine ...
# 106    Evaluation of Efficacy of Benztropine for Coca...
# 145    Combining N-of-1 Trials to Assess Fibromyalgia...
# 146    Efficacy of Valproate Maintenance in Bipolar A...
# 220                                                  NaN
# ...                                                  ...
# 19606  Comparıson Of Electromyography Results Before ...
# 19613  Efficacy of Structured Exercise-Nutritional In...
# 19616  Dexmedetomidine Compared With Ondansetron in T...
# 19623  Multicenter Randomized Double-blind Placebo-co...
# 19626  A Comparison Between The Effects Of Peribulbar...
#
#                                brief_summary_description  start_year
# 89     The purpose of this study is to evaluate naltr...      2003.0
# 106    The purpose of this study is to compare the ef...      2001.0
# 145    This study will compare the effectiveness of c...      2000.0
# 146    The purpose of this study is to test the effec...      2000.0
# 220    The purpose of this study is to learn more abo...      2000.0
# ...                                                  ...         ...
# 19606  Therefore, we aimed to evaluate the effectiven...      2021.0
# 19613  This is a prospective parallel group, double-b...      2022.0
# 19616  Evaluate the efficiency of management with int...      2020.0
# 19623  The purpose of this study is to assess the eff...      2023.0
# 19626  The aim of this study is to compare between pe...      2023.0
#
# [18609 rows x 8 columns]

# %%
reference_data_with_target_annotations.to_csv(f"data/annotated_aact/snomed_linking_outputs/{model_prefix}_annotations_with_details_{len(reference_data_with_target_annotations)}.csv")
