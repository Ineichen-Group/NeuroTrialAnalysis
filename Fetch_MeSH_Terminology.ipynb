# %%
from Bio import Entrez
import pandas as pd
import time

# %%
def parse_mesh_nodes(text):
    # Split the text into nodes. The first element is empty because of the leading '\n', so we discard it.
    nodes_raw = text.split('\n\n\n')[0:-1]  # Ignore the last split as it's empty after the final '\n\n\n'
    
    nodes = []
    for node in nodes_raw:
        node_dict = {}
        # Extract the title
        title_section = node.split('\n', 2)[1]
        #print(title_section)
        if "Supplementary Concept" in title_section:
            continue
        node_title = title_section.split(': ')[1].strip()
        node_dict['Title'] = node_title
        
        # Extract Entry Terms
        entry_terms_section = node.split('Entry Terms:\n')[1].split('\n\n')[0]  # Split at 'Entry Terms:\n' and get the first part
        entry_terms_list = [term.strip() for term in entry_terms_section.split('\n') if term.strip()]  # Remove any empty lines
        node_dict['Entry Terms'] = entry_terms_list
        
        # Extract All MeSH Categories
        all_mesh_categories_section = node.split('All MeSH Categories\n')[1].split('\n\n')[0]  # Split at 'All MeSH Categories' and get the first part
        all_mesh_categories_list = [category.strip() for category in all_mesh_categories_section.split('\n') if category.strip()]  # Remove any empty lines
        node_dict['All MeSH Categories'] = all_mesh_categories_list
        
        nodes.append(node_dict)
    
    return nodes

# %% [markdown]
# # Search from Start Nodes
# 1. Perform a search for each node using the Entrez E-utilities,
# 2. extract the ID list from the search results, fetch the records for those IDs,
# 3. parse the fetched records with a function you'll define (parse_mesh_nodes), and
# 4. finally concatenate the results into a pandas DataFrame.
#
# Relevant nodes:
# - Behavioral Symptoms [F01.145.126]
# - Neurobehavioral Manifestations [F01.700]
# - Mental Disorders [F03]

# %%
from urllib.error import HTTPError

# %%
def fetch_and_parse_node(tree_number):
    retries = 3  # Maximum number of retries
    for attempt in range(retries):
        try:
            # Search for the node using the Tree Number
            handle = Entrez.esearch(db="mesh", term=tree_number, retmax=1000)
            search_results = Entrez.read(handle)
            handle.close()
            
            # Extract the ID list from the results
            id_list = search_results['IdList']
            
            # Use the ID list to fetch the records
            if id_list:
                handle = Entrez.efetch(db="mesh", id=','.join(id_list))
                records = handle.read()
                handle.close()
                return parse_mesh_nodes(records)
            else:
                return []
        except HTTPError as e:
            if attempt < retries - 1:  # Check if it's not the last attempt
                print(f"Attempt {attempt + 1} failed with error {e}. Retrying in 10 seconds...")
                time.sleep(10)  # Wait for 10 seconds before retrying
            else:
                print(f"Attempt {attempt + 1} failed with error {e}. No more retries.")
                raise  # Re-raise the exception if all retries failed

# Tree Numbers for the nodes
tree_numbers = ['F01.145.126','F01.700', 'F03'] #, 'F01.700', 'F03'

# Fetch, parse, and aggregate data for all nodes
all_nodes_data = []
for tree_number in tree_numbers:
    node_data = fetch_and_parse_node(tree_number)
    all_nodes_data.extend(node_data)

# Convert the aggregated data into a pandas DataFrame
df = pd.DataFrame(all_nodes_data)

print(df)
# Out:
#                             Title  \
# 0             Behavioral Symptoms
# 1  Neurobehavioral Manifestations
# 2                Mental Disorders
#
#                                          Entry Terms  \
# 0  [Behavioral Symptom, Symptom, Behavioral, Symp...
# 1  [Manifestation, Neurobehavioral, Manifestation...
# 2  [Mental Disorder, Psychiatric Illness, Psychia...
#
#                                  All MeSH Categories
# 0  [Psychiatry and Psychology Category, Behavior ...
# 1  [Diseases Category, Nervous System Diseases, N...
# 2  [Psychiatry and Psychology Category, Mental Di...

# %%
df_exploded = df.explode('All MeSH Categories')
df_no_duplicates = df_exploded.drop_duplicates(subset=['All MeSH Categories'])

# %%
df_exploded.shape
# Out:
# (210, 3)

# %%
df_no_duplicates.shape
# Out:
# (196, 3)

# %%
df_no_duplicates.head()
# Out:
#                  Title                                        Entry Terms  \
# 0  Behavioral Symptoms  [Behavioral Symptom, Symptom, Behavioral, Symp...
# 0  Behavioral Symptoms  [Behavioral Symptom, Symptom, Behavioral, Symp...
# 0  Behavioral Symptoms  [Behavioral Symptom, Symptom, Behavioral, Symp...
# 0  Behavioral Symptoms  [Behavioral Symptom, Symptom, Behavioral, Symp...
# 0  Behavioral Symptoms  [Behavioral Symptom, Symptom, Behavioral, Symp...
#
#                    All MeSH Categories
# 0   Psychiatry and Psychology Category
# 0     Behavior and Behavior Mechanisms
# 0                             Behavior
# 0                  Behavioral Symptoms
# 0  Aberrant Motor Behavior in Dementia

# %%
df_no_duplicates.to_csv("./data/mesh_psychiatry_psychology.csv")

# %% [markdown]
# # Search for Terminology Synonyms

# %% [markdown]
# ## load reviewed terminology list

# %%
reviewed_mesh_terms = pd.read_csv("data/neuro_diseases_terminology/mesh_psychiatry_psychology_BVI.csv")
reviewed_mesh_terms.shape
# Out:
# (193, 4)

# %%
reviewed_mesh_terms_included = reviewed_mesh_terms[reviewed_mesh_terms['1=included, 0=excluded']==1]
reviewed_mesh_terms_included.shape
# Out:
# (185, 4)

# %%
reviewed_mesh_terms_included.columns = ["ignore", "mesh_category", "term", "inclusion_flag"]
reviewed_mesh_terms_included['term'] = reviewed_mesh_terms_included['term'].str.replace('+', '', regex=False).str.strip()
reviewed_mesh_terms_included = reviewed_mesh_terms_included[['mesh_category','term']]
reviewed_mesh_terms_included.head(5)
# Out:
# /var/folders/nd/2fzvhsh510gbt9x6z5pdb1gr0000gn/T/ipykernel_9275/1080373439.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviewed_mesh_terms_included['term'] = reviewed_mesh_terms_included['term'].str.replace('+', '', regex=False).str.strip()
#          mesh_category                                 term
# 1  Behavioral Symptoms  Aberrant Motor Behavior in Dementia
# 2  Behavioral Symptoms                           Aggression
# 3  Behavioral Symptoms                Psychomotor Agitation
# 4  Behavioral Symptoms                   Wandering Behavior
# 5  Behavioral Symptoms                   Affective Symptoms

# %%
manual_terms = pd.read_csv("data/neuro_diseases_terminology/bvi_manual_list.csv", header=0, names=['mesh_category','term'])
manual_terms['term'] = manual_terms['term'].str.replace(r'\([^)]*\)', '', regex=True).str.strip()
manual_terms.head(5)
# Out:
#                  mesh_category                            term
# 0  Psychiatry/mental disorders                      Depression
# 1  Psychiatry/mental disorders               Anxiety disorders
# 2  Psychiatry/mental disorders                Bipolar disorder
# 3  Psychiatry/mental disorders   Obsessive-compulsive disorder
# 4  Psychiatry/mental disorders  Post-traumatic stress disorder

# %%
terms_list_combined = pd.concat([reviewed_mesh_terms_included, manual_terms], ignore_index=True)

# %%
terms_list_combined.shape
# Out:
# (225, 2)

# %%
terms_list_combined_no_duplicates = terms_list_combined.drop_duplicates(subset=['All MeSH Categories'])
terms_list_combined.shape
# Out:
# (221, 2)

# %%
last_30_records = terms_list_combined_no_duplicates.tail(30)
last_30_records
# Out:
#                    mesh_category  \
# 195  Psychiatry/mental disorders
# 196  Psychiatry/mental disorders
# 197  Psychiatry/mental disorders
# 198  Psychiatry/mental disorders
# 199  Psychiatry/mental disorders
# 200  Psychiatry/mental disorders
# 201  Psychiatry/mental disorders
# 202  Psychiatry/mental disorders
# 203  Psychiatry/mental disorders
# 204  Psychiatry/mental disorders
# 205                    Neurology
# 206                    Neurology
# 207                    Neurology
# 208                    Neurology
# 209                    Neurology
# 210                    Neurology
# 211                    Neurology
# 212                    Neurology
# 213                    Neurology
# 214                    Neurology
# 215                    Neurology
# 216                    Neurology
# 217                    Neurology
# 218                    Neurology
# 219                    Neurology
# 220                    Neurology
# 221                    Neurology
# 222                    Neurology
# 223                    Neurology
# 224                    Neurology
#
#                                                   term
# 195                                            Phobias
# 196                    Borderline personality disorder
# 197                  Narcissistic personality disorder
# 198                    Antisocial personality disorder
# 199                             Dissociative disorders
# 200                            Substance use disorders
# 201                               Somatoform disorders
# 202                          Impulse-control disorders
# 203                                    Sleep disorders
# 204                               Adjustment disorders
# 205                                 Migraine, headache
# 206                                           Epilepsy
# 207                                             Stroke
# 208                                Alzheimer's disease
# 209                                Parkinson's disease
# 210                                 Multiple sclerosis
# 211                      Amyotrophic lateral sclerosis
# 212                               Huntington's disease
# 213                                       Bell's palsy
# 214                              Peripheral neuropathy
# 215                            Guillain-Barré syndrome
# 216                                     Cerebral palsy
# 217                        Duchenne muscular systrophy
# 218  Brain tumors, e.g., glioma, glioblastoma, meni...
# 219                                 Spinal cord injury
# 220                                      Hydrocephalus
# 221                                         Meningitis
# 222                                       Encephalitis
# 223                             Restless legs syndrome
# 224                               Trigeminal neuralgia

# %%
# Process each term in the DataFrame
nodes_list_30 = []
for term in last_30_records['term']:
    print(term)
    handle = Entrez.esearch(db="mesh", term=f"{term}[mh]", retmax=1000)
    record = Entrez.read(handle)
    id_list = record['IdList']
    retries = 3  # Maximum number of retries
    if id_list:
        for attempt in range(retries):
            try:
                handle = Entrez.efetch(db="mesh", id=id_list)
                records = handle.read()
                try:
                    nodes = parse_mesh_nodes(records)
                    nodes_list_30.extend(nodes)
                    break  # Success, so break out of the retry loop
                except Exception as parse_error:
                    # Handle parsing error specifically
                    print(f"Error parsing records for term '{term}'. Error: {parse_error}")
                    print(f"Problematic records:\n{records}")
                    break  # Break out of the retry loop, but continue with next term
            except HTTPError as e:
                if attempt < retries - 1:  # Check if it's not the last attempt
                    print(f"Attempt {attempt + 1} failed with error {e}. Retrying in 15 seconds...")
                    time.sleep(15)  # Wait for 10 seconds before retrying
                else:
                    print(f"Attempt {attempt + 1} failed with error {e}. No more retries.")
                    raise  # Re-raise the exception if all retries failed
        

# Assuming `nodes_list` is a list of dictionaries where each dictionary represents parsed information from each MeSH record
final_df_30 = pd.DataFrame(nodes_list_30)

# Display the final DataFrame
print(final_df_30)
# Out:
# Phobias
# Borderline personality disorder
# Narcissistic personality disorder
# Antisocial personality disorder
# Dissociative disorders
# Substance use disorders
# Somatoform disorders
# Impulse-control disorders
# Sleep disorders
# Adjustment disorders
# Migraine, headache
# Epilepsy
# Stroke
# Alzheimer's disease
# Parkinson's disease
# Multiple sclerosis
# Amyotrophic lateral sclerosis
# Huntington's disease
# Bell's palsy
# Peripheral neuropathy
# Guillain-Barré syndrome
# Cerebral palsy
# Duchenne muscular systrophy
# Brain tumors, e.g., glioma, glioblastoma, meningioma/meningeoma
# Spinal cord injury
# Hydrocephalus
# Meningitis
# Encephalitis
# Restless legs syndrome
# Trigeminal neuralgia
#                                                 Title  \
# 0                                    Phobic Disorders
# 1                     Borderline Personality Disorder
# 2                   Narcissistic Personality Disorder
# 3                     Antisocial Personality Disorder
# 4                              Dissociative Disorders
# 5                         Substance-Related Disorders
# 6                                Somatoform Disorders
# 7   Disruptive, Impulse Control, and Conduct Disor...
# 8                                Sleep Wake Disorders
# 9                                Adjustment Disorders
# 10                                           Epilepsy
# 11                                             Stroke
# 12                                  Alzheimer Disease
# 13                                  Parkinson Disease
# 14                                 Multiple Sclerosis
# 15                      Amyotrophic Lateral Sclerosis
# 16                                 Huntington Disease
# 17                                         Bell Palsy
# 18                 Peripheral Nervous System Diseases
# 19                            Guillain-Barre Syndrome
# 20                                     Cerebral Palsy
# 21                               Spinal Cord Injuries
# 22                                      Hydrocephalus
# 23                                         Meningitis
# 24                                       Encephalitis
# 25                             Restless Legs Syndrome
# 26                               Trigeminal Neuralgia
#
#                                           Entry Terms  \
# 0   [Disorder, Phobic, Phobic Disorder, Neuroses, ...
# 1   [Disorder, Borderline Personality, Borderline ...
# 2   [Personality Disorder, Narcissistic, Malignant...
# 3   [Antisocial Personality Disorders, Disorder, A...
# 4   [Disorder, Dissociative, Disorders, Dissociati...
# 5   [Substance Related Disorder, Disorder, Substan...
# 6   [Disorder, Somatoform, Somatoform Disorder, Me...
# 7   [Impulse Control Disorders, Disorders, Impulse...
# 8   [Disorder, Sleep Wake, Disorders, Sleep Wake, ...
# 9   [Reactive Disorders, Disorder, Reactive, Disor...
# 10  [Epilepsies, Seizure Disorder, Seizure Disorde...
# 11  [Strokes, Cerebrovascular Accident, Cerebrovas...
# 12  [Alzheimer Dementia, Alzheimer Dementias, Deme...
# 13  [Idiopathic Parkinson's Disease, Lewy Body Par...
# 14  [Sclerosis, Multiple, Sclerosis, Disseminated,...
# 15  [Sclerosis, Amyotrophic Lateral, Gehrig's Dise...
# 16  [Huntington Chorea, Chorea, Huntington, Huntin...
# 17  [Bell Palsies, Palsies, Bell, Palsy, Bell, Fac...
# 18  [Peripheral Nervous System Disease, PNS Diseas...
# 19  [Guillain Barre Syndrome, Syndrome, Guillain-B...
# 20  [CP (Cerebral Palsy), Cerebral Palsy, Dystonic...
# 21  [Spinal Cord Trauma, Cord Trauma, Spinal, Cord...
# 22  [Hydrocephaly, Cerebral Ventriculomegaly, Cere...
# 23  [Meningitides, Pachymeningitis, Pachymeningiti...
# 24  [Inflammation, Brain, Brain Inflammations, Bra...
# 25  [Restless Legs, Willis Ekbom Disease, Disease,...
# 26  [Neuralgia, Trigeminal, Trigeminal Neuralgias,...
#
#                                   All MeSH Categories
# 0   [Psychiatry and Psychology Category, Mental Di...
# 1   [Psychiatry and Psychology Category, Mental Di...
# 2   [Psychiatry and Psychology Category, Mental Di...
# 3   [Psychiatry and Psychology Category, Mental Di...
# 4   [Psychiatry and Psychology Category, Mental Di...
# 5   [Diseases Category, Chemically-Induced Disorde...
# 6   [Psychiatry and Psychology Category, Mental Di...
# 7   [Psychiatry and Psychology Category, Mental Di...
# 8   [Diseases Category, Nervous System Diseases, S...
# 9   [Psychiatry and Psychology Category, Mental Di...
# 10  [Diseases Category, Nervous System Diseases, C...
# 11  [Diseases Category, Nervous System Diseases, C...
# 12  [Diseases Category, Nervous System Diseases, C...
# 13  [Diseases Category, Nervous System Diseases, C...
# 14  [Diseases Category, Nervous System Diseases, A...
# 15  [Diseases Category, Nervous System Diseases, C...
# 16  [Diseases Category, Nervous System Diseases, C...
# 17  [Diseases Category, Infections, Virus Diseases...
# 18  [Diseases Category, Nervous System Diseases, N...
# 19  [Diseases Category, Nervous System Diseases, A...
# 20  [Diseases Category, Nervous System Diseases, C...
# 21  [Diseases Category, Nervous System Diseases, C...
# 22  [Diseases Category, Nervous System Diseases, C...
# 23  [Diseases Category, Nervous System Diseases, N...
# 24  [Diseases Category, Nervous System Diseases, C...
# 25  [Diseases Category, Nervous System Diseases, R...
# 26  [Diseases Category, Stomatognathic Diseases, M...

# %%
final_df_part1 = pd.DataFrame(nodes_list)

# %%
final_df_part1.tail()
# Out:
#                                 Title  \
# 177  Stress Disorders, Post-Traumatic
# 178      Feeding and Eating Disorders
# 179          Autism Spectrum Disorder
# 180                    Panic Disorder
# 181                  Phobic Disorders
#
#                                            Entry Terms  \
# 177  [Post-Traumatic Stress Disorder, Stress Disord...
# 178  [Eating and Feeding Disorders, Feeding Disorde...
# 179  [Autism Spectrum Disorders, Autistic Spectrum ...
# 180  [Disorder, Panic, Disorders, Panic, Panic Diso...
# 181  [Disorder, Phobic, Phobic Disorder, Neuroses, ...
#
#                                    All MeSH Categories
# 177  [Psychiatry and Psychology Category, Mental Di...
# 178  [Psychiatry and Psychology Category, Mental Di...
# 179  [Psychiatry and Psychology Category, Mental Di...
# 180  [Psychiatry and Psychology Category, Mental Di...
# 181  [Psychiatry and Psychology Category, Mental Di...

# %%
processed_terms_combined = pd.concat([final_df_part1, final_df_30], ignore_index=True)

# Extract the first element from 'All MeSH Categories' and rename the column to 'Disease Class'
processed_terms_combined['Disease Class'] = processed_terms_combined['All MeSH Categories'].apply(lambda x: x[0] if x else None)

# Keep the 'Title', 'Entry Terms', and 'Disease Class' columns
processed_terms_combined = processed_terms_combined[['Title', 'Entry Terms', 'Disease Class']]

# Explode the 'Entry Terms' column to create separate rows for each term
exploded_df = processed_terms_combined.explode('Entry Terms')

# Combine 'Title' and exploded 'Entry Terms' into one column, while keeping 'Disease Class' associated
combined_terms = pd.concat([
    exploded_df[['Entry Terms', 'Disease Class']].rename(columns={'Entry Terms': 'Neurological Disease'}),
    processed_terms_combined[['Title', 'Disease Class']].rename(columns={'Title': 'Neurological Disease'})
], ignore_index=True)

# %%
combined_terms[combined_terms['Neurological Disease']=="Depression"]
# Out:
#      Neurological Disease                       Disease Class
# 2899           Depression  Psychiatry and Psychology Category

# %%
combined_terms['Source'] = "MeSH"

# %%
combined_terms.head()
# Out:
#                          Neurological Disease  \
# 0   Disturbance in Motor Function in Dementia
# 1        Aberrant Motor Behaviors in Dementia
# 2  Disturbances in Motor Function in Dementia
# 3                       Agitation in Dementia
# 4                          Dementia Agitation
#
#                         Disease Class Source
# 0  Psychiatry and Psychology Category   MeSH
# 1  Psychiatry and Psychology Category   MeSH
# 2  Psychiatry and Psychology Category   MeSH
# 3  Psychiatry and Psychology Category   MeSH
# 4  Psychiatry and Psychology Category   MeSH

# %%
combined_terms.to_csv("data/neuro_diseases_terminology/diseases_dictionary_mesh_psych.csv")

# %% [markdown]
# ### terms not processed successfully

# %%
df2_renamed = terms_list_combined_no_duplicates.rename(columns={'term': 'Title'})
df2_renamed.head()
# Out:
#          mesh_category                                Title
# 0  Behavioral Symptoms  Aberrant Motor Behavior in Dementia
# 1  Behavioral Symptoms                           Aggression
# 2  Behavioral Symptoms                Psychomotor Agitation
# 3  Behavioral Symptoms                   Wandering Behavior
# 4  Behavioral Symptoms                   Affective Symptoms

# %%
df1 = processed_terms_combined.copy()
# Perform an outer join and use an indicator to track the source of each row
merged_df = pd.merge(df1, df2_renamed, on='Title', how='outer', indicator=True)

# Filter to keep only the rows from df2 (where the merge indicator is 'right_only')
non_matching_rows_df2 = merged_df[merged_df['_merge'] == 'right_only']

# Drop the merge indicator column and any columns from df1 that were added to the result
final_df = non_matching_rows_df2.drop(columns=['_merge'] + list(df1.columns.difference(['Title'])))

# %%
final_df
# Out:
#                                                  Title  \
# 3                                 Adjustment disorders
# 11                        Alice in Wonderland Syndrome
# 14                                 Alzheimer's disease
# 18                       Amyotrophic lateral sclerosis
# 23                     Antisocial personality disorder
# 26                                   Anxiety disorders
# 30            Attention-deficit/hyperactivity disorder
# 33                            Autism spectrum disorder
# 36                                        Bell's palsy
# 39                       Bipolar and Related Disorders
# 40                                    Bipolar disorder
# 45                     Borderline personality disorder
# 46   Brain tumors, e.g., glioma, glioblastoma, meni...
# 53                                      Cerebral palsy
# 84                              Dissociative disorders
# 88                         Duchenne muscular systrophy
# 90                                         Dyspareunia
# 92                                    Eating disorders
# 96                                          Encopresis
# 97                                            Enuresis
# 113                            Guillain-Barré syndrome
# 119                               Huntington's disease
# 123                          Impulse-control disorders
# 129                                           Lethargy
# 130                                        Malingering
# 140                                 Migraine, headache
# 143                                    Motor Disorders
# 146                                 Multiple sclerosis
# 150                  Narcissistic personality disorder
# 165                      Obsessive-compulsive disorder
# 170                                     Panic disorder
# 177                                Parkinson's disease
# 182                              Peripheral neuropathy
# 186                                            Phobias
# 192                     Post-traumatic stress disorder
# 204                             Restless legs syndrome
# 217                        Sexual and Gender Disorders
# 220                                    Sleep disorders
# 223                               Somatoform disorders
# 225                                 Spinal cord injury
# 236                            Substance use disorders
# 245                               Trigeminal neuralgia
# 247                                         Vaginismus
#
#                       mesh_category
# 3       Psychiatry/mental disorders
# 11   Neurobehavioral Manifestations
# 14                        Neurology
# 18                        Neurology
# 23      Psychiatry/mental disorders
# 26      Psychiatry/mental disorders
# 30      Psychiatry/mental disorders
# 33      Psychiatry/mental disorders
# 36                        Neurology
# 39                 Mental Disorders
# 40      Psychiatry/mental disorders
# 45      Psychiatry/mental disorders
# 46                        Neurology
# 53                        Neurology
# 84      Psychiatry/mental disorders
# 88                        Neurology
# 90                 Mental Disorders
# 92      Psychiatry/mental disorders
# 96              Behavioral Symptoms
# 97              Behavioral Symptoms
# 113                       Neurology
# 119                       Neurology
# 123     Psychiatry/mental disorders
# 129  Neurobehavioral Manifestations
# 130             Behavioral Symptoms
# 140                       Neurology
# 143                Mental Disorders
# 146                       Neurology
# 150     Psychiatry/mental disorders
# 165     Psychiatry/mental disorders
# 170     Psychiatry/mental disorders
# 177                       Neurology
# 182                       Neurology
# 186     Psychiatry/mental disorders
# 192     Psychiatry/mental disorders
# 204                       Neurology
# 217                Mental Disorders
# 220     Psychiatry/mental disorders
# 223     Psychiatry/mental disorders
# 225                       Neurology
# 236     Psychiatry/mental disorders
# 245                       Neurology
# 247                Mental Disorders

# %% [markdown]
# ## combine with icd and mesh dictionary

# %%
psych_df = pd.read_csv("data/neuro_diseases_terminology/diseases_dictionary_mesh_psych.csv",index_col=0)

# %%
psych_df.shape
# Out:
# (3097, 3)

# %%
psych_df.head(5)
# Out:
#                          Neurological Disease  \
# 0   Disturbance in Motor Function in Dementia
# 1        Aberrant Motor Behaviors in Dementia
# 2  Disturbances in Motor Function in Dementia
# 3                       Agitation in Dementia
# 4                          Dementia Agitation
#
#                         Disease Class Source
# 0  Psychiatry and Psychology Category   MeSH
# 1  Psychiatry and Psychology Category   MeSH
# 2  Psychiatry and Psychology Category   MeSH
# 3  Psychiatry and Psychology Category   MeSH
# 4  Psychiatry and Psychology Category   MeSH

# %%
neuro_df = pd.read_csv("data/neuro_diseases_terminology/diseases_dictionary_mesh_icd_flat.csv")

# %%
neuro_df.shape
# Out:
# (16519, 3)

# %%
neuro_df.head()
# Out:
#                                 Neurological Disease Source  \
# 0  1-methyl-4-phenyl-1,2,3,6-tetrahydropyridine i...    ICD
# 1                      11p Partial Monosomy Syndrome   MeSH
# 2                         3s, Spinocerebellar Ataxia   MeSH
# 3                                          47,XX,+21   MeSH
# 4                                          47,XY,+21   MeSH
#
#                     Disease Class
# 0  Diseases of the nervous system
# 1       Neurologic Manifestations
# 2      Neurodegenerative Diseases
# 3       Neurologic Manifestations
# 4       Neurologic Manifestations

# %%
combined_all_df = pd.concat([neuro_df, psych_df], ignore_index=True)

# %%
combined_all_df.shape
# Out:
# (19616, 3)

# %%
combined_all_df.head()
# Out:
#                                 Neurological Disease Source  \
# 0  1-methyl-4-phenyl-1,2,3,6-tetrahydropyridine i...    ICD
# 1                      11p Partial Monosomy Syndrome   MeSH
# 2                         3s, Spinocerebellar Ataxia   MeSH
# 3                                          47,XX,+21   MeSH
# 4                                          47,XY,+21   MeSH
#
#                     Disease Class
# 0  Diseases of the nervous system
# 1       Neurologic Manifestations
# 2      Neurodegenerative Diseases
# 3       Neurologic Manifestations
# 4       Neurologic Manifestations

# %%
combined_all_df_no_dups = combined_all_df.drop_duplicates(subset=['Neurological Disease'])
combined_all_df_no_dups.shape
# Out:
# (18830, 3)

# %%
combined_all_df_no_dups[combined_all_df_no_dups['Neurological Disease'] == 'Depression']
# Out:
#       Neurological Disease Source                       Disease Class
# 19418           Depression   MeSH  Psychiatry and Psychology Category

# %%
combined_all_df_no_dups.to_csv("data/neuro_diseases_terminology/diseases_dictionary_mesh_icd_flat_20240313.csv")

# %% [markdown]
# ### hieararchical representation

# %%
processed_terms_combined = pd.concat([final_df_part1, final_df_30], ignore_index=True)

# Extract the first element from 'All MeSH Categories' and rename the column to 'Disease Class'
processed_terms_combined['Disease Class'] = processed_terms_combined['All MeSH Categories'].apply(lambda x: x[0] if x else None)

# Keep the 'Title', 'Entry Terms', and 'Disease Class' columns
processed_terms_combined = processed_terms_combined[['Title', 'Entry Terms', 'Disease Class']]

# %%
processed_terms_combined = processed_terms_combined.rename(columns={'Title': 'MeSH Common name', 'Entry Terms': 'MeSH Synonyms', 'Disease Class': 'MeSH Disease Class'})
processed_terms_combined['MeSH Synonyms'] = processed_terms_combined['MeSH Synonyms'].apply(lambda x: " | ".join(x))
processed_terms_combined.head()
# Out:
#                       MeSH Common name  \
# 0  Aberrant Motor Behavior in Dementia
# 1                           Aggression
# 2                Psychomotor Agitation
# 3                   Wandering Behavior
# 4                   Affective Symptoms
#
#                                        MeSH Synonyms  \
# 0  Disturbance in Motor Function in Dementia | Ab...
# 1                                        Aggressions
# 2  Psychomotor Hyperactivity | Hyperactivity, Psy...
# 3                                Behavior, Wandering
# 4  Affective Symptom | Symptom, Affective | Sympt...
#
#                    MeSH Disease Class
# 0  Psychiatry and Psychology Category
# 1  Psychiatry and Psychology Category
# 2                   Diseases Category
# 3  Psychiatry and Psychology Category
# 4  Psychiatry and Psychology Category

# %%
neuro_df_hierarachy = pd.read_csv("data/neuro_diseases_terminology/diseases_dictionary_mesh_icd.csv")

# %%
neuro_df_hierarachy.head()
# Out:
#                               ICD Node URI  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4  http://id.who.int/icd/entity/1289874444
#
#                            ICD Parent URI     Mesh ID  \
# 0                                     NaN  D000069279
# 1                                     NaN  D000069281
# 2                                     NaN  D000069544
# 3                                     NaN  D000070607
# 4  http://id.who.int/icd/entity/699015578  D000070624
#
#                                    MeSH Tree Number        ICD Title  \
# 0                               C10.228.140.490.125              NaN
# 1                       C10.228.140.617.738.275.500              NaN
# 2              C10.228.228.399| C10.228.140.430.520              NaN
# 3                               C10.668.829.600.375              NaN
# 4  C10.228.140.199.444.375| C10.900.300.087.235.375  Brain contusion
#
#           MeSH Common name               MeSH Disease Class  \
# 0  Drug Resistant Epilepsy  Central Nervous System Diseases
# 1  Autoimmune Hypophysitis  Central Nervous System Diseases
# 2  Infectious Encephalitis  Central Nervous System Diseases
# 3           Morton Neuroma           Neuromuscular Diseases
# 4          Brain Contusion  Central Nervous System Diseases
#
#                 ICD Disease Class  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4  Diseases of the nervous system
#
#                                        MeSH Synonyms
# 0  Refractory Epilepsy, Drug| Epilepsies, Drug Re...
# 1  Autoimmune Hypophysitides| Hypophysitis, Lymph...
# 2  Infectious Encephalitis| Encephalitis, Infectious
# 3  Morton's Metatarsalgia| Neuroma, Morton| Neuro...
# 4  Contusion, Brain| Contusio Cerebri| Brain Cont...

# %%
neuro_df_hierarachy.shape, processed_terms_combined.shape
# Out:
# ((8130, 9), (209, 3))

# %%
processed_terms_combined[processed_terms_combined['MeSH Common name']=='Depression']
# Out:
#    MeSH Common name                                      MeSH Synonyms  \
# 11       Depression  Depressive Symptoms | Depressive Symptom | Sym...
#
#                     MeSH Disease Class
# 11  Psychiatry and Psychology Category

# %%
combined_all_df_hierarchical = pd.concat([neuro_df_hierarachy, processed_terms_combined], ignore_index=True)

# %%
combined_all_df_hierarchical.head()
# Out:
#                               ICD Node URI  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4  http://id.who.int/icd/entity/1289874444
#
#                            ICD Parent URI     Mesh ID  \
# 0                                     NaN  D000069279
# 1                                     NaN  D000069281
# 2                                     NaN  D000069544
# 3                                     NaN  D000070607
# 4  http://id.who.int/icd/entity/699015578  D000070624
#
#                                    MeSH Tree Number        ICD Title  \
# 0                               C10.228.140.490.125              NaN
# 1                       C10.228.140.617.738.275.500              NaN
# 2              C10.228.228.399| C10.228.140.430.520              NaN
# 3                               C10.668.829.600.375              NaN
# 4  C10.228.140.199.444.375| C10.900.300.087.235.375  Brain contusion
#
#           MeSH Common name               MeSH Disease Class  \
# 0  Drug Resistant Epilepsy  Central Nervous System Diseases
# 1  Autoimmune Hypophysitis  Central Nervous System Diseases
# 2  Infectious Encephalitis  Central Nervous System Diseases
# 3           Morton Neuroma           Neuromuscular Diseases
# 4          Brain Contusion  Central Nervous System Diseases
#
#                 ICD Disease Class  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4  Diseases of the nervous system
#
#                                        MeSH Synonyms
# 0  Refractory Epilepsy, Drug| Epilepsies, Drug Re...
# 1  Autoimmune Hypophysitides| Hypophysitis, Lymph...
# 2  Infectious Encephalitis| Encephalitis, Infectious
# 3  Morton's Metatarsalgia| Neuroma, Morton| Neuro...
# 4  Contusion, Brain| Contusio Cerebri| Brain Cont...

# %%
combined_all_df_hierarchical.shape
# Out:
# (8339, 9)

# %%
combined_all_df_hierarchical.to_csv("data/neuro_diseases_terminology/diseases_dictionary_mesh_icd_2024.csv")

# %%
combined_all_df_hierarchical[combined_all_df_hierarchical['MeSH Common name']=='Depression']
# Out:
#      ICD Node URI ICD Parent URI Mesh ID MeSH Tree Number ICD Title  \
# 8141          NaN            NaN     NaN              NaN       NaN
#
#      MeSH Common name                  MeSH Disease Class ICD Disease Class  \
# 8141       Depression  Psychiatry and Psychology Category               NaN
#
#                                           MeSH Synonyms
# 8141  Depressive Symptoms | Depressive Symptom | Sym...
